# %%
# imports
import os
import requests as re
import pandas as pd
from pprint import pprint

# %%
# Foursquare API keys
fs_api = os.environ["FS_API_KEY"]
fs_id = os.environ["FS_ID"]
fs_secret = os.environ["FS_SECRET"]

# Yelp API key
yelp_api = os.environ["YELP_API"]

# %%
# coordinates for the Calgary Stampede
stamp_coords = "51.0379,-114.0532"

# %% [markdown]
# # Yelp

# %% [markdown]
# I will set up a function that will retrieve business data from the Yelp API. The function takes in the latitude and longitude coordinates and makes a request to the API using the appropriate API key that was loaded in previously.

# %%
def get_yelp(lat_long, query="", radius=1000):
    lat_long = lat_long.split(sep=",")
    
    yelp_url = "https://api.yelp.com/v3/businesses/search"
    
    header = {"Authorization": f"Bearer {yelp_api}"}
    
    yelp_params = {"latitude": lat_long[0],
               "longitude": lat_long[1],
               "radius": radius}
    
    return re.get(yelp_url, params=yelp_params, headers=header).json()

# %%
yelp_venues = get_yelp(stamp_coords)
# pprint(yelp_venues)
type(yelp_venues)
# Out:
# dict

# %% [markdown]
# The request retrieves a json file in the form of a dictionary. The file contains businesses within a 1000m radius of the Calgary Stampede. I will normalize the data using the key "businesses" to access and explore the nested information.

# %%
df_yelp = pd.json_normalize(yelp_venues, record_path=["businesses"])
df_yelp.head()
# Out:
#                        id                                        alias  \
# 0  tXoO9Uc_tQ8_IqTmEQcW5w                    village-ice-cream-calgary
# 1  SKhV8mF40RcsGrJjkuEwvw                       ten-foot-henry-calgary
# 2  vggAigqfXUqSakdVZe3zJw                           zcrew-cafe-calgary
# 3  kmOeRAvOL1oR6Z-4Ggdx6w                  charcut-roast-house-calgary
# 4  336_K7i9-jrEhvQleGUVQw  grumans-catering-and-delicatessen-calgary-2
#
#                               name  \
# 0                Village Ice Cream
# 1                   Ten Foot Henry
# 2                       ZCREW Cafe
# 3              Charcut Roast House
# 4  Grumans Catering & Delicatessen
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/t2p0z8...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/iEGzWX...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/cD-2Dx...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/gUmXlR...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/HYIZld...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/village-ice-cream-cal...           300
# 1  https://www.yelp.com/biz/ten-foot-henry-calgar...           425
# 2  https://www.yelp.com/biz/zcrew-cafe-calgary?ad...            65
# 3  https://www.yelp.com/biz/charcut-roast-house-c...           336
# 4  https://www.yelp.com/biz/grumans-catering-and-...            85
#
#                                           categories  rating transactions  \
# 0  [{'alias': 'icecream', 'title': 'Ice Cream & F...     4.5           []
# 1  [{'alias': 'newcanadian', 'title': 'Canadian (...     4.5           []
# 2             [{'alias': 'cafes', 'title': 'Cafes'}]     4.5           []
# 3       [{'alias': 'steak', 'title': 'Steakhouses'}]     4.0           []
# 4  [{'alias': 'delis', 'title': 'Delis'}, {'alias...     4.5           []
#
#    ... coordinates.latitude coordinates.longitude        location.address1  \
# 0  ...            51.042919           -114.054319         431 10 Avenue SE
# 1  ...            51.041090           -114.065970       1209 1st Street SW
# 2  ...            51.041992           -114.055583        401 11 Avenue  SE
# 3  ...            51.044727           -114.063370  101-899 Centre Street S
# 4  ...            51.042590           -114.059271       230 11th Avenue SE
#
#    location.address2  location.address3  location.city location.zip_code  \
# 0                                              Calgary           T2G 0W3
# 1                                              Calgary           T2R 0V3
# 2                                  None        Calgary           T2G 0Y5
# 3                                              Calgary           T2G 1B8
# 4                                              Calgary           T2G 0X8
#
#   location.country location.state  \
# 0               CA             AB
# 1               CA             AB
# 2               CA             AB
# 3               CA             AB
# 4               CA             AB
#
#                             location.display_address
# 0    [431 10 Avenue SE, Calgary, AB T2G 0W3, Canada]
# 1  [1209 1st Street SW, Calgary, AB T2R 0V3, Canada]
# 2   [401 11 Avenue  SE, Calgary, AB T2G 0Y5, Canada]
# 3  [101-899 Centre Street S, Calgary, AB T2G 1B8,...
# 4  [230 11th Avenue SE, Calgary, AB T2G 0X8, Canada]
#
# [5 rows x 24 columns]

# %%
# What are the columns?
print(df_yelp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        20 non-null     object
#  1   alias                     20 non-null     object
#  2   name                      20 non-null     object
#  3   image_url                 20 non-null     object
#  4   is_closed                 20 non-null     bool
#  5   url                       20 non-null     object
#  6   review_count              20 non-null     int64
#  7   categories                20 non-null     object
#  8   rating                    20 non-null     float64
#  9   transactions              20 non-null     object
#  10  price                     19 non-null     object
#  11  phone                     20 non-null     object
#  12  display_phone             20 non-null     object
#  13  distance                  20 non-null     float64
#  14  coordinates.latitude      20 non-null     float64
#  15  coordinates.longitude     20 non-null     float64
#  16  location.address1         20 non-null     object
#  17  location.address2         18 non-null     object
#  18  location.address3         18 non-null     object
#  19  location.city             20 non-null     object
#  20  location.zip_code         20 non-null     object
#  21  location.country          20 non-null     object
#  22  location.state            20 non-null     object
#  23  location.display_address  20 non-null     object
# dtypes: bool(1), float64(4), int64(1), object(18)
# memory usage: 3.7+ KB
# None

# %%
print(df_yelp.shape)
# Out:
# (20, 24)

# %% [markdown]
# The dataframe has 20 rows and 24 columns. Looking at the available columns, I want to extract the necessary information and store them in a new dataframe.

# %%
# putting desired columns into a dataframe and renaming some columns
yelp_data = df_yelp[["name", 
                     "review_count", 
                     "rating", 
                     "categories", 
                     "price", 
                     "location.address1",
                     "location.city",
                     "location.zip_code",
                     "coordinates.latitude", 
                     "coordinates.longitude"]].reindex()

yelp_data.rename(columns={"location.address1": "address",
                     "location.city": "city",
                     "location.zip_code": "postal_code",
                     "coordinates.latitude": "latitude",
                     "coordinates.longitude": "longitude"},
                     inplace=True)
yelp_data.head()
# Out:
#                               name  review_count  rating  \
# 0                Village Ice Cream           300     4.5
# 1                   Ten Foot Henry           425     4.5
# 2                       ZCREW Cafe            65     4.5
# 3              Charcut Roast House           336     4.0
# 4  Grumans Catering & Delicatessen            85     4.5
#
#                                           categories price  \
# 0  [{'alias': 'icecream', 'title': 'Ice Cream & F...    $$
# 1  [{'alias': 'newcanadian', 'title': 'Canadian (...   $$$
# 2             [{'alias': 'cafes', 'title': 'Cafes'}]   NaN
# 3       [{'alias': 'steak', 'title': 'Steakhouses'}]   $$$
# 4  [{'alias': 'delis', 'title': 'Delis'}, {'alias...    $$
#
#                    address     city postal_code   latitude   longitude
# 0         431 10 Avenue SE  Calgary     T2G 0W3  51.042919 -114.054319
# 1       1209 1st Street SW  Calgary     T2R 0V3  51.041090 -114.065970
# 2        401 11 Avenue  SE  Calgary     T2G 0Y5  51.041992 -114.055583
# 3  101-899 Centre Street S  Calgary     T2G 1B8  51.044727 -114.063370
# 4       230 11th Avenue SE  Calgary     T2G 0X8  51.042590 -114.059271

# %% [markdown]
# Next, I will convert the price column into an integer. [Yelp](https://www.yelp.com/developers/documentation/v3/business_search) uses the dollar($) symbol to denote price levels ranging from 1-4.

# %%
yelp_copy = yelp_data.copy()
yelp_copy.loc[yelp_copy["price"] == "$", "price"] = 1
yelp_copy.loc[yelp_copy["price"] == "$$", "price"] = 2
yelp_copy.loc[yelp_copy["price"] == "$$$", "price"] = 3
yelp_copy.loc[yelp_copy["price"] == "$$$$", "price"] = 4  

yelp_copy.rename(columns={"price": "price_level"}, inplace=True)

# %%
yelp_copy
# Out:
#                                name  review_count  rating  \
# 0                 Village Ice Cream           300     4.5
# 1                    Ten Foot Henry           425     4.5
# 2                        ZCREW Cafe            65     4.5
# 3               Charcut Roast House           336     4.0
# 4   Grumans Catering & Delicatessen            85     4.5
# 5                              N9NA           136     4.0
# 6                Red's Diner Ramsay           102     4.0
# 7                Proof Cocktail Bar            65     4.5
# 8                      One18 Empire            87     4.5
# 9                    Manuel Latruwe            56     4.0
# 10                     Klein Harris            64     4.5
# 11            Sweet Relief Pastries            29     5.0
# 12                      Studio Bell            21     5.0
# 13                          Saltlik           159     3.5
# 14            Rosso Coffee Roasters            69     4.0
# 15               Yellow Door Bistro           101     3.5
# 16            Rosso Coffee Roasters            47     4.5
# 17                           Teatro           102     3.5
# 18                      Deane House            46     4.0
# 19                              Koi            75     4.0
#
#                                            categories price_level  \
# 0   [{'alias': 'icecream', 'title': 'Ice Cream & F...           2
# 1   [{'alias': 'newcanadian', 'title': 'Canadian (...           3
# 2              [{'alias': 'cafes', 'title': 'Cafes'}]         NaN
# 3        [{'alias': 'steak', 'title': 'Steakhouses'}]           3
# 4   [{'alias': 'delis', 'title': 'Delis'}, {'alias...           2
# 5   [{'alias': 'newcanadian', 'title': 'Canadian (...           2
# 6   [{'alias': 'diners', 'title': 'Diners'}, {'ali...           2
# 7   [{'alias': 'cocktailbars', 'title': 'Cocktail ...           2
# 8   [{'alias': 'cocktailbars', 'title': 'Cocktail ...           2
# 9   [{'alias': 'bakeries', 'title': 'Bakeries'}, {...           3
# 10  [{'alias': 'desserts', 'title': 'Desserts'}, {...           2
# 11       [{'alias': 'bakeries', 'title': 'Bakeries'}]           2
# 12  [{'alias': 'musicvenues', 'title': 'Music Venu...           2
# 13  [{'alias': 'steak', 'title': 'Steakhouses'}, {...           3
# 14  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...           2
# 15  [{'alias': 'newcanadian', 'title': 'Canadian (...           3
# 16  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...           2
# 17  [{'alias': 'italian', 'title': 'Italian'}, {'a...           3
# 18  [{'alias': 'newcanadian', 'title': 'Canadian (...           2
# 19  [{'alias': 'asianfusion', 'title': 'Asian Fusi...           2
#
#                     address     city postal_code   latitude   longitude
# 0          431 10 Avenue SE  Calgary     T2G 0W3  51.042919 -114.054319
# 1        1209 1st Street SW  Calgary     T2R 0V3  51.041090 -114.065970
# 2         401 11 Avenue  SE  Calgary     T2G 0Y5  51.041992 -114.055583
# 3   101-899 Centre Street S  Calgary     T2G 1B8  51.044727 -114.063370
# 4        230 11th Avenue SE  Calgary     T2G 0X8  51.042590 -114.059271
# 5        121 17th Avenue SE  Calgary     T2G 1H3  51.037710 -114.062240
# 6       1101- 8th Street SE  Calgary     T2G 2Z6  51.039960 -114.041900
# 7        1302 1st Street SW  Calgary     T2R 0V7  51.040455 -114.065637
# 8       820 Centre Street S  Calgary     T2G 5J2  51.044979 -114.062876
# 9          1333 1 Street SE  Calgary     T2G 5L1  51.040067 -114.061180
# 10          110 8 Avenue SW  Calgary     T2P 1B3  51.045664 -114.063681
# 11            120 13 Ave SW  Calgary     T2R 0V2  51.040695 -114.064308
# 12          850 4 Street SE  Calgary     T2G 1R1  51.044929 -114.052996
# 13          101 8 Avenue SW  Calgary     T2P 1B4  51.045430 -114.063290
# 14          140 8 Avenue SE  Calgary     T2G 5J2  51.045618 -114.061946
# 15         119 12 Avenue SW  Calgary     T2R 0G8  51.041355 -114.064491
# 16       803 24th Avenue SE  Calgary     T2G 4G5  51.031780 -114.043512
# 17        200 8th Avenue SE  Calgary     T2G 0K7  51.045712 -114.060287
# 18        806 9th Avenue SE  Calgary     T2G 0S2  51.043595 -114.041884
# 19         1011 1 Street SW  Calgary     T2R 1J2  51.042838 -114.065894

# %%
yelp_copy.to_excel("yelp_venue_data.xlsx", index=False)

# %% [markdown]
# # Foursquare

# %% [markdown]
# The Foursquare data extraction process is similar to the one performed for Yelp API.

# %%
def get_4sq(lat_long, radius=1000):
    fs_url = "https://api.foursquare.com/v3/places/search"

    params = {
        "radius": 1000, 
        "ll": lat_long}

    headers = {
        "Accept": "application/json",
        "Authorization": fs_api}

    return re.get(fs_url, params=params, headers=headers).json()

# %%
fs_venues = get_4sq(stamp_coords)
# pprint(fs_venues)
# type(fs_venues)

# %%
df_4sq = pd.json_normalize(fs_venues, record_path="results")
df_4sq.head()
# Out:
#                      fsq_id  \
# 0  4b15508cf964a520c3b023e3
# 1  4c07e4e798e69c743fe3c61d
# 2  4b3aa7e2f964a5200a6c25e3
# 3  4b0586ecf964a520d37522e3
# 4  518ae730454a31c3d02f473d
#
#                                           categories chains  distance  \
# 0  [{'id': 10051, 'name': 'Stadium', 'icon': {'pr...     []        77
# 1  [{'id': 10039, 'name': 'Music Venue', 'icon': ...     []        67
# 2  [{'id': 13022, 'name': 'Sports Bar', 'icon': {...     []        85
# 3  [{'id': 16030, 'name': 'Other Great Outdoors',...     []       243
# 4  [{'id': 13072, 'name': 'Asian Restaurant', 'ic...     []       322
#
#                                   link                   name  \
# 0  /v3/places/4b15508cf964a520c3b023e3  Scotiabank Saddledome
# 1  /v3/places/4c07e4e798e69c743fe3c61d        Nashville North
# 2  /v3/places/4b3aa7e2f964a5200a6c25e3               Dutton's
# 3  /v3/places/4b0586ecf964a520d37522e3       Stampede Grounds
# 4  /v3/places/518ae730454a31c3d02f473d            Zen 8 Grill
#
#            timezone  geocodes.main.latitude  geocodes.main.longitude  \
# 0  America/Edmonton               51.037431              -114.052107
# 1  America/Edmonton               51.034746              -114.055400
# 2  America/Edmonton               51.037241              -114.053007
# 3  America/Edmonton               51.036874              -114.056286
# 4  America/Edmonton               51.040895              -114.054694
#
#    geocodes.roof.latitude  ...  location.country  \
# 0               51.037431  ...                CA
# 1               51.034746  ...                CA
# 2               51.037241  ...                CA
# 3                     NaN  ...                CA
# 4               51.040895  ...                CA
#
#                           location.formatted_address location.locality  \
# 0         555 Saddledome Rise SE, Calgary AB T2G 2W1           Calgary
# 1  Stampede Park (Stampede Trail SE), Calgary AB ...           Calgary
# 2                            Olympic Way, Calgary AB           Calgary
# 3            1410 Olympic Way SE, Calgary AB T2G 2W1           Calgary
# 4    412 12th Ave SE (3rd St SE), Calgary AB T2G 1A5           Calgary
#
#   location.neighborhood location.postcode location.region  \
# 0              [Erlton]           T2G 2W1              AB
# 1              [Erlton]           T2G 2W1              AB
# 2                   NaN                                AB
# 3                   NaN           T2G 2W1              AB
# 4       [Victoria Park]           T2G 1A5              AB
#
#                              related_places.children location.cross_street  \
# 0  [{'name': 'The Club'}, {'fsq_id': '6281b1b26b6...                   NaN
# 1                                                NaN     Stampede Trail SE
# 2                                                NaN
# 3  [{'fsq_id': '5d4895a23350fe0008abe1fb', 'name'...                   NaN
# 4                                                NaN             3rd St SE
#
#   related_places.parent.fsq_id related_places.parent.name
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 22 columns]

# %%
df_4sq.shape
# Out:
# (10, 22)

# %%
df_4sq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fsq_id                        10 non-null     object
#  1   categories                    10 non-null     object
#  2   chains                        10 non-null     object
#  3   distance                      10 non-null     int64
#  4   link                          10 non-null     object
#  5   name                          10 non-null     object
#  6   timezone                      10 non-null     object
#  7   geocodes.main.latitude        10 non-null     float64
#  8   geocodes.main.longitude       10 non-null     float64
#  9   geocodes.roof.latitude        9 non-null      float64
#  10  geocodes.roof.longitude       9 non-null      float64
#  11  location.address              9 non-null      object
#  12  location.country              10 non-null     object
#  13  location.formatted_address    10 non-null     object
#  14  location.locality             10 non-null     object
#  15  location.neighborhood         4 non-null      object
#  16  location.postcode             10 non-null     object
#  17  location.region               10 non-null     object
#  18  related_places.children       3 non-null      object
#  19  location.cross_street         4 non-null      object
#  20  related_places.parent.fsq_id  2 non-null      object
#  21  related_places.parent.name    2 non-null      object
# dtypes: float64(4), int64(1), object(17)
# memory usage: 1.8+ KB

# %% [markdown]
# The Foursquare API returned 10 records and 22 columns. Because I will be comparing Foursquare to Yelp, I want to extract information similar to Yelp. From the available columns, these are the name of the business, categories, address, city, zip code, latitude, longitude. Unfortunately, Foursquare does not provide review counts and ratings.

# %%
# storing desired data in a dataframe
fs_data = df_4sq[["name",
                  "categories", 
                  "location.address",
                  "location.locality",
                  "location.postcode",
                  "geocodes.main.latitude", 
                  "geocodes.main.longitude"]].reindex()

# renaming certain columns
fs_data.rename(columns={"location.address": "address",
                  "location.locality": "city",
                  "location.postcode": "postal_code",   
                  "geocodes.main.latitude": "latitude",
                  "geocodes.main.longitude": "longitude"},
                  inplace=True)
fs_data
# Out:
#                       name                                         categories  \
# 0    Scotiabank Saddledome  [{'id': 10051, 'name': 'Stadium', 'icon': {'pr...
# 1          Nashville North  [{'id': 10039, 'name': 'Music Venue', 'icon': ...
# 2                 Dutton's  [{'id': 13022, 'name': 'Sports Bar', 'icon': {...
# 3         Stampede Grounds  [{'id': 16030, 'name': 'Other Great Outdoors',...
# 4              Zen 8 Grill  [{'id': 13072, 'name': 'Asian Restaurant', 'ic...
# 5  Calgary Flames FanAttic  [{'id': 17043, 'name': 'Clothing Store', 'icon...
# 6          Stampede Corral  [{'id': 18000, 'name': 'Sports and Recreation'...
# 7         Saddleroom Grill  [{'id': 13049, 'name': 'Diner', 'icon': {'pref...
# 8      Stampede Grandstand  [{'id': 18039, 'name': 'Race Track', 'icon': {...
# 9            Scotsman Hill  [{'id': 16032, 'name': 'Park', 'icon': {'prefi...
#
#                   address     city postal_code   latitude   longitude
# 0  555 Saddledome Rise SE  Calgary     T2G 2W1  51.037431 -114.052107
# 1           Stampede Park  Calgary     T2G 2W1  51.034746 -114.055400
# 2             Olympic Way  Calgary              51.037241 -114.053007
# 3     1410 Olympic Way SE  Calgary     T2G 2W1  51.036874 -114.056286
# 4         412 12th Ave SE  Calgary     T2G 1A5  51.040895 -114.054694
# 5  555 Saddledome Rise SE  Calgary     T2G 2W1  51.038085 -114.051557
# 6       10 Roundup Way SE  Calgary     T2G 2W1  51.037526 -114.054859
# 7  555 Saddledome Rise SE  Calgary     T2G 2W1  51.037506 -114.051780
# 8     1410 Olympic Way SE  Calgary     T2G 2W1  51.033675 -114.055181
# 9                     NaN  Calgary              51.036773 -114.046421

# %%
fs_data.to_excel("foursquare_venue_data.xlsx", index=False)

# %% [markdown]
# # Creating a SQLite Database

# %%
import sqlite3
from sqlite3 import Error

# %%
def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

def execute_query(connection, query):
    """executes the query and returns whether or not it was successful"""
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")
        
def execute_read_query(connection, query):
    """return results query"""
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as e:
        print(f"The error '{e}' occurred")

# %%
connection = create_connection("stampede_venues.sqlite")
# Out:
# Connection to SQLite DB successful

# %%
# creating tables to store information from the Yelp and Foursquare API
yelp_table = """
CREATE TABLE IF NOT EXISTS yelp_table(
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name VARCHAR(30) NOT NULL,
    review_count INTEGER,
    rating FLOAT,
    categories VARCHAR(50),
    price_level INTEGER,
    address VARCHAR(30),
    city VARCHAR(30),
    postal_code VARCHAR(10),
    latitude FLOAT NOT NULL,
    longitude FLOAT NOT NULL
);
"""

fs_table = """
CREATE TABLE IF NOT EXISTS fs_table(
    fs_id INTEGER PRIMARY KEY AUTOINCREMENT,
    name VARCHAR(30) NOT NULL,
    categories VARCHAR(50),
    address VARCHAR(30),
    city VARCHAR(30),
    postal_code VARCHAR(10),
    latitude FLOAT NOT NULL,
    longitude FLOAT NOT NULL
);
"""

# %%
execute_query(connection, yelp_table)
execute_query(connection, fs_table)
# Out:
# Query executed successfully
# Query executed successfully

# %%
yelp_sql = pd.read_excel("yelp_venue_data.xlsx")
fs_sql = pd.read_excel("foursquare_venue_data.xlsx")

# %%
yelp_sql.to_sql("yelp_table", connection, if_exists="replace", index=True)
fs_sql.to_sql("fs_table",connection, if_exists="replace", index=True)
# Out:
# 10

# %% [markdown]
# # Results

# %% [markdown]
# #### Which API has the best coverage?

# %% [markdown]
# During the data exploration process, Yelp was able to retrieve 20 venues, while Foursquare retrieved 10. Yelp has the better coverage based on the number of records returned.

# %% [markdown]
# #### Top 10 businesses

# %% [markdown]
# According to Yelp, the top businesses within 1000m of the Calgary Stampede, based on ratings are:

# %%
top10 = """
    SELECT name, rating
    FROM yelp_table
    ORDER BY rating DESC
    LIMIT 10
    """

execute_read_query(connection, top10)
# Out:
# [('Sweet Relief Pastries', 5.0),
#  ('Studio Bell', 5.0),
#  ('Village Ice Cream', 4.5),
#  ('Ten Foot Henry', 4.5),
#  ('ZCREW Cafe', 4.5),
#  ('Grumans Catering & Delicatessen', 4.5),
#  ('Proof Cocktail Bar', 4.5),
#  ('One18 Empire', 4.5),
#  ('Klein Harris', 4.5),
#  ('Rosso Coffee Roasters', 4.5)]

# %% [markdown]
# There were no ratings information from the Foursquare API.
